# %% [markdown]
# Data File ==> DataFrame, Numpy (전처리) ==> Tensor ==> Dataset(피처 + 타겟) ==> DataLoader 생성

# %% [markdown]
# ### Dataset & DataLoader 살펴보기
# - Pytorch에서 배치크기만 데이터를 조절하기 위한 메카니즘
# - Dataset : 사용 데이터를 기반으로 사용자 정의 클래스 작성
# - DataLoader : 지정된 Dataset에서 지정된 batch size만큼 피처와 타겟을 추출하여 전달

# %% [markdown]
# [1] 모듈로딩 및 데이터 준비

# %%
### ===> 모듈 로딩
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import numpy as np
import pandas as pd

# %% [markdown]
# [2] 데이터셋 생성

# %% [markdown]
# - 사용자 정의 데이터셋 생성

# %%
file = '../data/iris.csv'
irisDF = pd.read_csv(file, header = None)
irisDF.columns = ['sepal_length', 'sepal_width', 'petal_length','petal_width','variety']
irisDF
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         variety
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
irisNP = np.loadtxt(file, delimiter = ',', usecols = [0,1,2,3])
irisNP
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
# 데이터의 타입 체크
type(irisDF), type(irisNP), irisDF.__class__.__name__, irisNP.__class__.__name__
# Out:
# (pandas.core.frame.DataFrame, numpy.ndarray, 'DataFrame', 'ndarray')

# %%
if irisDF.__class__.__name__ == 'DataFrame' :
    print('DF')
else:
    print('-----')
# Out:
# DF

# %%
print(isinstance(irisDF, pd.DataFrame), isinstance(irisNP, pd.DataFrame), isinstance(irisDF, np.ndarray),isinstance(irisNP, np.ndarray), sep = '\n')
# Out:
# True
# False
# False
# True

# %%
### 사용자 정의 DataSet 클래스
# - 데이터의 Tensor 변환

class DLDataset(Dataset):
    # 초기화 함수 콜백함수 (callback function)
    def __init__(self, x_data, y_data):
        super().__init__()
        
        # x,y 데이터 ==> ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data
        y_data = y_data.values if isinstance(y_data, pd.DataFrame) else y_data
        # 넘파이면 그대로 ㄱㅊ    다만 데이터프레임이면 values만 뺴서 갖고오자능
        
        # ndarray ==> tensor
        self.feature = torch.FloatTensor(x_data)
        self.target = torch.LongTensor(y_data)         # 라벨 인코딩 형식으로 진행함 (원핫인코딩 ㄴㄴ)
        
    # 데이터셋의 개수 체크 함수 콜백함수 (callback function)
    def __len__(self):
        return self.target.shape[0]
    
    # 특정 인덱스 데이터 + 라벨 반환 콜백함수 (callback function)
    def __getitem__(self, index):
        return self.feature[index], self.target[index]

# %%
## 피처와 라벨로 분리
featureDF = irisDF[irisDF.columns[:-1]]
targetDF = irisDF[irisDF.columns[-1]]

print(f"featureDF => {featureDF.shape} , {featureDF.ndim}D")
print(f"targetDF => {targetDF.shape} , {targetDF.ndim}D")
# Out:
# featureDF => (150, 4) , 2D
# targetDF => (150,) , 1D

# %%
# object 타입 타겟 ===> int 타입 타겟 변환
from sklearn.preprocessing import LabelEncoder

targetNP = LabelEncoder().fit_transform(targetDF)
targetNP = targetNP.reshape(-1,1)
print(targetNP.shape, targetNP.ndim)
# Out:
# (150, 1) 2

# %%
# 데이터셋 생성  ==> DF, NP
my_dataset = DLDataset(featureDF, targetNP)

# %%
print(my_dataset[0], featureDF.iloc[0], targetDF[0], sep = '\n\n')
# Out:
# (tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0]))
#
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64
#
# Iris-setosa

# %%
# 데이터셋 생성 => NP, NP
my_dataset2 = DLDataset(irisNP, targetNP)
print(my_dataset2[0])
# Out:
# (tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0]))

# %% [markdown]
# - [2-3] 학습용, 검증용, 테스트용 Dataset <hr>

# %%
### ===> 파이토치
from torch.utils.data import random_split

# 학습용, 검증용, 테스트 데이터 비율
seed = torch.Generator().manual_seed(2)

trainDS, validDS, testDS = random_split(my_dataset2, [0.7, 0.1, 0.2], generator = seed )

print(f"trainDS => {len(trainDS)}, validDS => {len(validDS)}, testDS => {len(testDS)}")
# Out:
# trainDS => 105, validDS => 15, testDS => 30

# %%
print(f"Subset 속성 =>\n indices: \n {trainDS.indices} \n dataset : {trainDS.dataset}")
# Out:
# Subset 속성 =>
#  indices:
#  [48, 81, 63, 33, 30, 84, 24, 49, 10, 117, 40, 128, 89, 87, 115, 53, 35, 97, 80, 5, 20, 75, 59, 64, 43, 60, 90, 0, 127, 86, 125, 111, 26, 47, 120, 65, 107, 118, 21, 116, 148, 67, 124, 70, 55, 46, 15, 18, 29, 8, 132, 22, 106, 101, 144, 133, 51, 9, 4, 85, 32, 78, 23, 41, 136, 14, 36, 140, 142, 17, 71, 68, 98, 108, 103, 3, 145, 141, 39, 146, 54, 109, 93, 28, 147, 58, 112, 149, 38, 61, 104, 52, 122, 44, 138, 31, 6, 42, 69, 134, 130, 66, 110, 12, 139]
#  dataset : <__main__.DLDataset object at 0x000001D2B2A90DF0>

# %%
print(f"Subset 속성 =>\n indices: \n {validDS.indices} \n dataset : {validDS.dataset}")
# Out:
# Subset 속성 =>
#  indices:
#  [77, 102, 11, 19, 7, 143, 123, 25, 129, 34, 2, 16, 27, 74, 83]
#  dataset : <__main__.DLDataset object at 0x000001D2B2A90DF0>

# %% [markdown]
# [3] DataLoader 생성 : 학습용, 검증용, 테스트용 <hr>

# %%
# DataLoader 생성
# drop_last 매개변수 : 배치 사이즈로 데이터셋 분리 후 남는 데이터 처리 방법 설정 [기본 : False]
batch = 10
trainDL = DataLoader(trainDS, batch_size = batch)
validDL = DataLoader(validDS, batch_size = batch)
testDL = DataLoader(testDS, batch_size = batch)

len(trainDL), len(validDL), len(testDL)
# Out:
# (11, 2, 3)

# %%
# Epoch당 반복 단위
print(f'batch_size : {batch}')
print(f"trainDS => {len(trainDS)}개, validDS => {len(validDS)}개, trainDS => {len(trainDS)}개")
print(f"trainDL => {len(trainDL)}개, validDL => {len(validDL)}개, testDL => {len(testDL)}개")
# Out:
# batch_size : 10
# trainDS => 105개, validDS => 15개, trainDS => 105개
# trainDL => 11개, validDL => 2개, testDL => 3개

# %% [markdown]
# [4] Model 클래스 정의 : 입/출력 피처수, 층 수, 은닉층의 노드수 <hr>
# - 구조설계
#     * 입력층 : 입력 <= 피처 갯수, iris 4개
#     * 은닉층 : 마음대로 알아서 잘
#     * 출력층 : 출력 <= [분류] 타겟 클래스 갯수  [회귀] 1개

# %%
# 모델 클래스 정의
# 클래스명 : CModel

class CModel(nn.Module):    # nn.Module을 상속받는다.
    
    # 모델 구성 요소 정의 함수
    def __init__(self, in_, out_):
        super().__init__()
        self.input_layer = nn.Linear(in_, 100)
        self.relu = nn.ReLU()
        self.hidden_layer = nn.Linear(100, 27)
        self.output_layer = nn.Linear(27, out_)
        
    # 순방향 학습 진행
    def forward(self, x):
        x = self.input_layer(x)            # W1x1 + W2x2 _ ... + Wnxn + b 반환
        x = self.relu(x)                   # relu 함수 결과 100개 반환
        x = self.hidden_layer(x)
        x = self.relu(x)
        x = self.output_layer(x)
        return x

# %% [markdown]
# [5] 학습 준비 : 실행 디바이스, 모델, 최적화, 손실함수, 학습 횟수, 학습 함수, 평가 함수, 예측 함수 <hr>

# %%
# 실행 디바이스 설정
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# 학습 횟수
EPOCHS = 50

# %%
# 모델 인스턴스
IN, OUT = my_dataset2.feature.shape[1], len(np.unique(targetDF))
print(IN, OUT)
model = CModel(IN, OUT).to(DEVICE)
# Out:
# 4 3

# %%
# 손실 함수
LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)

# 최적화 인스턴스
import torch.optim as optim
OPTIMIZER = optim.Adam(model.parameters())

# %% [markdown]
# - 학습 및 검증 관련 함수 정의

# %%
### ===> 학습 진행 함수
def training():
    # 학습 모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화
    model.train()
    
    # 배치 크기만큼 학습 진행 및 저장
    train_loss = []
    for cnt, (feature, target) in enumerate(trainDL):
        # print(cnt, feature, target)
        # 배치 크기만큼의 학습 데이터 준비      
        feature, target = feature.to(DEVICE), target.to(DEVICE)
        
        target = target.squeeze()
        
        # 학습
        pre_target = model(feature)
        print(f"pre_target => {pre_target.shape}, {pre_target.ndim}D")
        print(f"target => {target.shape}, {target.ndim}D")
        
        
        # 손실 계산
        loss = LOSS_FN(pre_target, target)
        train_loss.append(loss)
        
        # W, b 업데이트
        OPTIMIZER.zero_grad()
        loss.backward()
        OPTIMIZER.step()
        
        # 배치 단위 학습 진행 메시지 출력
        print(f"[Train {cnt} batch LOSS] ===> {loss}")
        
    # 에포크 단위 학습 진행 메시지 출력
    print(f"[Train loss] ===> {loss}")
    
    return train_loss

# %%
### ===> 검증 및 평가 진행 함수
def testing():
    pass

# %%
### ===> 예측 함수
def predict():
    pass

# %% [markdown]
# [6] 학습 진행 <hr>

# %%
for eps in range(EPOCHS):
    # 학습
    train_loss = training()
    
    # 검증
    # testing()
    
    print(f"[{eps}/{EPOCHS}] {sum(train_loss)/len(train_loss)}")
# Out:
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.983521580696106
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 1.1552753448486328
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 1.0536985397338867
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 1.3102928400039673
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.972711443901062
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 1.1456689834594727
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.9869710206985474
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 1.1264712810516357
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 1.044304370880127
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.9932564496994019
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 1.057816743850708
# [Train loss] ===> 1.057816743850708
# [0/50] 1.075453519821167
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.8866266012191772
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.9467411041259766
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.9637876749038696
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.9029843211174011
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.8813900947570801
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.8813884854316711
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.7981137037277222
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.9023500680923462
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.9153054356575012
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.8112842440605164
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.8211830258369446
# [Train loss] ===> 0.8211830258369446
# [1/50] 0.8828322887420654
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.8257275819778442
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.9311896562576294
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 1.0128024816513062
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.689361572265625
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.8004380464553833
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.7443164587020874
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.647658109664917
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.799808144569397
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.8408764004707336
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.6997413039207458
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.7162007093429565
# [Train loss] ===> 0.7162007093429565
# [2/50] 0.7916473150253296
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.7195464372634888
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.8473889231681824
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.9299799203872681
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.6027329564094543
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.6850957870483398
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.6588759422302246
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.5337845087051392
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.7311735153198242
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.7577964067459106
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.022783324122428894
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.10586770623922348
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.04992293193936348
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.06272442638874054
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.1582660973072052
# [Train loss] ===> 0.1582660973072052
# [41/50] 0.07516949623823166
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.07526233047246933
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.04778865724802017
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.08286997675895691
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.025067400187253952
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11799619346857071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.06601700931787491
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.02163795568048954
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.10317953675985336
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.04734135419130325
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.06157425791025162
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.1541013866662979
# [Train loss] ===> 0.1541013866662979
# [42/50] 0.07298509776592255
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.0729614645242691
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.045078907161951065
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.0799231082201004
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.023704281076788902
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11696970462799072
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.06486957520246506
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.020600758492946625
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.10069538652896881
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.04491686075925827
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.06049665808677673
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.15017105638980865
# [Train loss] ===> 0.15017105638980865
# [43/50] 0.07094433903694153
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.07067234814167023
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.042496271431446075
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.07716047018766403
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.022512074559926987
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11581561714410782
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.06392534077167511
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.019623879343271255
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.09837356209754944
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.042637038975954056
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.05936140939593315
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.14614222943782806
# [Train loss] ===> 0.14614222943782806
# [44/50] 0.068974569439888
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.06877395510673523
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.04025707766413689
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.07458934932947159
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.02132221683859825
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11497709900140762
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.0629928782582283
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.018723439425230026
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.09619445353746414
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.04056501016020775
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.058475393801927567
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.1425706297159195
# [Train loss] ===> 0.1425706297159195
# [45/50] 0.06722194701433182
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.06671231985092163
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.03805826976895332
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.07216955721378326
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.020259371027350426
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11415976285934448
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.06212100386619568
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.01789853349328041
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.09417861700057983
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.03857382759451866
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.05750659853219986
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.13897106051445007
# [Train loss] ===> 0.13897106051445007
# [46/50] 0.06550990790128708
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.06486149877309799
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.036043427884578705
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.06990013271570206
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.019293632358312607
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.1132572740316391
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.0614338144659996
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.017098788172006607
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.09225517511367798
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.036771733313798904
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.05669524148106575
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.1356067955493927
# [Train loss] ===> 0.1356067955493927
# [47/50] 0.06392886489629745
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.06306944042444229
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.03418548032641411
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.06776637583971024
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.01834670640528202
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11264890432357788
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.060666609555482864
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.01638062298297882
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.09050139784812927
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.03504294157028198
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.05586954206228256
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.13234850764274597
# [Train loss] ===> 0.13234850764274597
# [48/50] 0.062438782304525375
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 0 batch LOSS] ===> 0.06133062765002251
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 1 batch LOSS] ===> 0.03241642564535141
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 2 batch LOSS] ===> 0.06576278060674667
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 3 batch LOSS] ===> 0.017515426501631737
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 4 batch LOSS] ===> 0.11185864359140396
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 5 batch LOSS] ===> 0.060091812163591385
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 6 batch LOSS] ===> 0.015684353187680244
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 7 batch LOSS] ===> 0.0888328105211258
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 8 batch LOSS] ===> 0.033468421548604965
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
# [Train 9 batch LOSS] ===> 0.055185336619615555
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [Train 10 batch LOSS] ===> 0.1293104887008667
# [Train loss] ===> 0.1293104887008667
# [49/50] 0.06104155629873276

# %%
# DataLoader 속성
for _ , (feature, target) in enumerate(trainDL):
    print(f"[{_}] feature {feature.shape}")
    ## 로더에서 가지고온 데이터만큼 학습 진행
# Out:
# [0] feature torch.Size([10, 4])
# [1] feature torch.Size([10, 4])
# [2] feature torch.Size([10, 4])
# [3] feature torch.Size([10, 4])
# [4] feature torch.Size([10, 4])
# [5] feature torch.Size([10, 4])
# [6] feature torch.Size([10, 4])
# [7] feature torch.Size([10, 4])
# [8] feature torch.Size([10, 4])
# [9] feature torch.Size([10, 4])
# [10] feature torch.Size([5, 4])
