# %% [markdown]
# Data File ==> DataFrame, Numpy (전처리) ==> Tensor ==> Dataset(피처 + 타겟) ==> DataLoader 생성

# %% [markdown]
# ### Dataset & DataLoader 살펴보기
# - Pytorch에서 배치크기만 데이터를 조절하기 위한 메카니즘
# - Dataset : 사용 데이터를 기반으로 사용자 정의 클래스 작성
# - DataLoader : 지정된 Dataset에서 지정된 batch size만큼 피처와 타겟을 추출하여 전달

# %% [markdown]
# [1] 모듈로딩 및 데이터 준비

# %%
### ===> 모듈 로딩
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import numpy as np
import pandas as pd

# %% [markdown]
# [2] 데이터셋 생성

# %% [markdown]
# - 사용자 정의 데이터셋 생성

# %%
file = '../data/iris.csv'
irisDF = pd.read_csv(file, header = None)
irisDF.columns = ['sepal_length', 'sepal_width', 'petal_length','petal_width','variety']

# %%
irisNP = np.loadtxt(file, delimiter = ',', usecols = [0,1,2,3])

# %%
# 데이터의 타입 체크
type(irisDF), type(irisNP), irisDF.__class__.__name__, irisNP.__class__.__name__
# Out:
# (pandas.core.frame.DataFrame, numpy.ndarray, 'DataFrame', 'ndarray')

# %%
if irisDF.__class__.__name__ == 'DataFrame' :
    print('DF')
else:
    print('-----')
# Out:
# DF

# %%
print(isinstance(irisDF, pd.DataFrame), isinstance(irisNP, pd.DataFrame), isinstance(irisDF, np.ndarray),isinstance(irisNP, np.ndarray), sep = '\n')
# Out:
# True
# False
# False
# True

# %%
### 사용자 정의 DataSet 클래스
# - 데이터의 Tensor 변환

class DLDataset(Dataset):
    # 초기화 함수 콜백함수 (callback function)
    def __init__(self, x_data, y_data):
        super().__init__()
        
        # x,y 데이터 ==> ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data
        y_data = y_data.values if isinstance(y_data, pd.DataFrame) else y_data
        # 넘파이면 그대로 ㄱㅊ    다만 데이터프레임이면 values만 뺴서 갖고오자능
        
        # ndarray ==> tensor
        self.feature = torch.FloatTensor(x_data)
        self.target = torch.LongTensor(y_data)         # 라벨 인코딩 형식으로 진행함 (원핫인코딩 ㄴㄴ)
        
    # 데이터셋의 개수 체크 함수 콜백함수 (callback function)
    def __len__(self):
        return self.target.shape[0]
    
    # 특정 인덱스 데이터 + 라벨 반환 콜백함수 (callback function)
    def __getitem__(self, index):
        return self.feature[index], self.target[index]

# %%
## 피처와 라벨로 분리
featureDF = irisDF[irisDF.columns[:-1]]
targetDF = irisDF[irisDF.columns[-1]]

print(f"featureDF => {featureDF.shape} , {featureDF.ndim}D")
print(f"targetDF => {targetDF.shape} , {targetDF.ndim}D")
# Out:
# featureDF => (150, 4) , 2D
# targetDF => (150,) , 1D

# %%
# object 타입 타겟 ===> int 타입 타겟 변환
from sklearn.preprocessing import LabelEncoder

targetNP = LabelEncoder().fit_transform(targetDF)
targetNP = targetNP.reshape(-1,1)
print(targetNP.shape, targetNP.ndim)
# Out:
# (150, 1) 2

# %%
# 데이터셋 생성  ==> DF, NP
my_dataset = DLDataset(featureDF, targetNP)

# %%
print(my_dataset[0], featureDF.iloc[0], targetDF[0], sep = '\n\n')
# Out:
# (tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0]))
#
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64
#
# Iris-setosa

# %%
# 데이터셋 생성 => NP, NP
my_dataset2 = DLDataset(irisNP, targetNP)
print(my_dataset2[0])
# Out:
# (tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0]))

# %% [markdown]
# - [2-3] 학습용, 검증용, 테스트용 Dataset <hr>

# %%
### ===> 파이토치
from torch.utils.data import random_split

# 학습용, 검증용, 테스트 데이터 비율
seed = torch.Generator().manual_seed(2)

trainDS, validDS, testDS = random_split(my_dataset2, [0.7, 0.1, 0.2], generator = seed )

print(f"trainDS => {len(trainDS)}, validDS => {len(validDS)}, testDS => {len(testDS)}")
# Out:
# trainDS => 105, validDS => 15, testDS => 30

# %%
# print(f"Subset 속성 =>\n indices: \n {trainDS.indices} \n dataset : {trainDS.dataset}")

# %%
# print(f"Subset 속성 =>\n indices: \n {validDS.indices} \n dataset : {validDS.dataset}")

# %% [markdown]
# [3] DataLoader 생성 : 학습용, 검증용, 테스트용 <hr>

# %%
# DataLoader 생성
# drop_last 매개변수 : 배치 사이즈로 데이터셋 분리 후 남는 데이터 처리 방법 설정 [기본 : False]
batch = 10
trainDL = DataLoader(trainDS, batch_size = batch)
validDL = DataLoader(validDS, batch_size = batch)
testDL = DataLoader(testDS, batch_size = batch)

len(trainDL), len(validDL), len(testDL)
# Out:
# (11, 2, 3)

# %%
# Epoch당 반복 단위
print(f'batch_size : {batch}')
print(f"trainDS => {len(trainDS)}개, validDS => {len(validDS)}개, trainDS => {len(trainDS)}개")
print(f"trainDL => {len(trainDL)}개, validDL => {len(validDL)}개, testDL => {len(testDL)}개")
# Out:
# batch_size : 10
# trainDS => 105개, validDS => 15개, trainDS => 105개
# trainDL => 11개, validDL => 2개, testDL => 3개

# %% [markdown]
# [4] Model 클래스 정의 : 입/출력 피처수, 층 수, 은닉층의 노드수 <hr>
# - 구조설계
#     * 입력층 : 입력 <= 피처 갯수, iris 4개
#     * 은닉층 : 마음대로 알아서 잘
#     * 출력층 : 출력 <= [분류] 타겟 클래스 갯수  [회귀] 1개

# %%
# 모델 클래스 정의
# 클래스명 : CModel

class CModel(nn.Module):    # nn.Module을 상속받는다.
    
    # 모델 구성 요소 정의 함수
    def __init__(self, in_, out_):
        super().__init__()
        self.input_layer = nn.Linear(in_, 100)
        self.relu = nn.ReLU()
        self.hidden_layer = nn.Linear(100, 27)
        self.output_layer = nn.Linear(27, out_)
        
    # 순방향 학습 진행
    def forward(self, x):
        x = self.input_layer(x)            # W1x1 + W2x2 _ ... + Wnxn + b 반환
        x = self.relu(x)                   # relu 함수 결과 100개 반환
        x = self.hidden_layer(x)
        x = self.relu(x)
        x = self.output_layer(x)
        return x

# %% [markdown]
# [5] 학습 준비 : 실행 디바이스, 모델, 최적화, 손실함수, 학습 횟수, 학습 함수, 평가 함수, 예측 함수 <hr>

# %%
# 실행 디바이스 설정
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# 학습 횟수
EPOCHS = 50

# %%
# 모델 인스턴스
IN, OUT = my_dataset2.feature.shape[1], len(np.unique(targetDF))
print(IN, OUT)
model = CModel(IN, OUT).to(DEVICE)
# Out:
# 4 3

# %%
# 손실 함수
LOSS_FN = nn.CrossEntropyLoss().to(DEVICE)

# 최적화 인스턴스
import torch.optim as optim
OPTIMIZER = optim.Adam(model.parameters())

# %% [markdown]
# - 학습 및 검증 관련 함수 정의

# %%
import torchmetrics.functional as metrics

# %%
### ===> 학습 진행 함수
def training():
    # 학습 모드 => 정규화, 경사하강법, 드랍아웃 등의 기능 활성화
    model.train()
    
    # 배치 크기만큼 학습 진행 및 저장
    train_loss = []
    for cnt, (feature, target) in enumerate(trainDL):
        # print(cnt, feature, target)
        # 배치 크기만큼의 학습 데이터 준비      
        feature, target = feature.to(DEVICE), target.to(DEVICE)
        
        target = target.squeeze()
        
        # 학습
        pre_target = model(feature)
        print(f"pre_target => {pre_target.shape}, {pre_target.ndim}D")
        print(f"target => {target.shape}, {target.ndim}D")
        
        
        # 손실 계산
        loss = LOSS_FN(pre_target, target)
        train_loss.append(loss)
        
        # W, b 업데이트
        OPTIMIZER.zero_grad()
        loss.backward()
        OPTIMIZER.step()
        
        # 배치 단위 학습 진행 메시지 출력
        # print(f"[Train {cnt} batch LOSS] ===> {loss}")
        
        
        # 
        acc = metrics.accuracy(pre_target, target, task = 'multiclass', num_classes = OUT)
        print(f" ACC : {acc}")
        
        
        
    # 에포크 단위 학습 진행 메시지 출력
    print(f"[Train loss] ===> {loss}")
    print(f" TOOOOOOOOOOOOOOOOOOOOTAL         ACC : {acc}")
    return train_loss

# %%
### ===> 검증 및 평가 진행 함수
def testing():
    pass

# %%
### ===> 예측 함수
def predict():
    pass

# %% [markdown]
# [6] 학습 진행 <hr>

# %%
for eps in range(EPOCHS):
    # 학습
    train_loss = training()
    
    # 검증
    # testing()
    
    print(f"[{eps}/{EPOCHS}] {sum(train_loss)/len(train_loss)}")
# Out:
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.30000001192092896
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.5
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.10000000149011612
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.5
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.5
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.20000000298023224
# [Train loss] ===> 1.1589680910110474
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.20000000298023224
# [0/50] 1.096333384513855
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.4000000059604645
# [Train loss] ===> 1.0165821313858032
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.4000000059604645
# [1/50] 0.9661773443222046
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.4000000059604645
# [Train loss] ===> 0.9426175951957703
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.4000000059604645
# [2/50] 0.8828237652778625
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.5
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.4000000059604645
# [Train loss] ===> 0.8679541349411011
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.4000000059604645
# [3/50] 0.8033074736595154
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.4000000059604645
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.6000000238418579
# [Train loss] ===> 0.784314751625061
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.6000000238418579
# [4/50] 0.7218466997146606
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.711371660232544
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [5/50] 0.649812638759613
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.6360793709754944
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [6/50] 0.5831739902496338
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.5814544558525085
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [7/50] 0.5296260714530945
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.5355532169342041
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [8/50] 0.48517295718193054
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.6000000238418579
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.5073663592338562
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [9/50] 0.45071715116500854
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.48548442125320435
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [10/50] 0.4210464358329773
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.699999988079071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.46528059244155884
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [11/50] 0.3943031132221222
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.4503293037414551
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [12/50] 0.3707379400730133
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.43445760011672974
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [13/50] 0.3472609221935272
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.421752393245697
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [14/50] 0.32593026757240295
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.406710684299469
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [15/50] 0.3051984906196594
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.800000011920929
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 0.800000011920929
# [Train loss] ===> 0.39419475197792053
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 0.800000011920929
# [16/50] 0.2865007221698761
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.3806307911872864
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [17/50] 0.2683345079421997
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.3675655424594879
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [18/50] 0.25146275758743286
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.35624924302101135
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [19/50] 0.23591071367263794
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.34330156445503235
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [20/50] 0.22092129290103912
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.3329804539680481
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [21/50] 0.20779715478420258
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.3211232125759125
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [22/50] 0.19489751756191254
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.3105643689632416
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [23/50] 0.1836254745721817
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.3007696270942688
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [24/50] 0.1731838583946228
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.29041019082069397
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [25/50] 0.16341806948184967
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.28152766823768616
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [26/50] 0.1548381745815277
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.27238646149635315
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [27/50] 0.1466798037290573
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.2643067240715027
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [28/50] 0.13949106633663177
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.25574633479118347
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [29/50] 0.13262377679347992
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.24878613650798798
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [30/50] 0.12669624388217926
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.24082283675670624
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [31/50] 0.1207880973815918
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.2335118055343628
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [32/50] 0.1156347319483757
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.22732701897621155
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [33/50] 0.11100932955741882
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.22113578021526337
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [34/50] 0.10652149468660355
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.2152433842420578
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [35/50] 0.10242000222206116
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.20970073342323303
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [36/50] 0.09864126890897751
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.20413605868816376
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [37/50] 0.09509590268135071
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.19848895072937012
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [38/50] 0.09175233542919159
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.19344735145568848
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [39/50] 0.08877439796924591
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.18825873732566833
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [40/50] 0.08588284999132156
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.1836511343717575
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [41/50] 0.0832548439502716
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.17873236536979675
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [42/50] 0.08069496601819992
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.17440684139728546
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [43/50] 0.0783843919634819
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.17012500762939453
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [44/50] 0.07615313678979874
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.16590918600559235
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [45/50] 0.07404667139053345
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.16224880516529083
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [46/50] 0.07216792553663254
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.15799662470817566
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [47/50] 0.07020625472068787
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.15451034903526306
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [48/50] 0.0685097947716713
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 0.8999999761581421
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([10, 3]), 2D
# target => torch.Size([10]), 1D
#  ACC : 1.0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
#  ACC : 1.0
# [Train loss] ===> 0.15095320343971252
#  TOOOOOOOOOOOOOOOOOOOOTAL         ACC : 1.0
# [49/50] 0.06686363369226456

# %%
# DataLoader 속성
for _ , (feature, target) in enumerate(trainDL):
    print(f"[{_}] feature {feature.shape}")
    ## 로더에서 가지고온 데이터만큼 학습 진행
# Out:
# [0] feature torch.Size([10, 4])
# [1] feature torch.Size([10, 4])
# [2] feature torch.Size([10, 4])
# [3] feature torch.Size([10, 4])
# [4] feature torch.Size([10, 4])
# [5] feature torch.Size([10, 4])
# [6] feature torch.Size([10, 4])
# [7] feature torch.Size([10, 4])
# [8] feature torch.Size([10, 4])
# [9] feature torch.Size([10, 4])
# [10] feature torch.Size([5, 4])
